# %%
# %run TMA.ipynb
# X = np.array([-1,0,1])
# Y = np.array([0,1,4])
def splineCoefficients3(X,Y,A,B):
    N = X.shape[0]-1
    aCoef = np.zeros(N)
    bCoef = np.zeros(N)
   
    dCoef = np.zeros(N)
   
    fVector = np.diff(Y)
    hVector = np.diff(X)
    
    cCoef = np.zeros(N+1)
    FVector = np.zeros(N+1)
        
    FVector[0] = 3*(fVector[0]/hVector[0]-A)/hVector[0]
    FVector[N] = B
    for i in range(1,N):
        FVector[i] = 6*(fVector[i]/hVector[i] - fVector[i-1]/hVector[i-1])
        
    print(f'f_(i+1)-f_(i): {fVector}')
    print(f'x_(i+1)-x_(i): {hVector}')
    print(f'F: {FVector}')

    aDiag = np.zeros(N)
    bDiag = np.zeros(N)
    cDiag = np.zeros(N+1)
    
    cDiag[0] = 1
    bDiag[0] = 0
    cDiag[N] = 1
    aDiag[N-1] = 0

    for i in range(1, N):
        aDiag[i-1] = hVector[i-1]
        cDiag[i] = 2*(hVector[i-1]+hVector[i])
        bDiag[i] = hVector[i]
       
    cCoef = TMA(aDiag, bDiag, cDiag, FVector)
    
    for i in range (N):
        aCoef[i] = Y[i+1]
        
    for i in range(1,N):
        dCoef[i] = (cCoef[i+1]-cCoef[i])
        dCoef[i] = dCoef[i] / hVector[i-1]

    dCoef[0] = (cCoef[1]-cCoef[0])
    dCoef[0] = dCoef[0]/hVector[0]
    
    # bCoef[N-1]=B
    for i in range(0,N):
        bCoef[i] = hVector[i]*cCoef[i+1]/2- hVector[i]*hVector[i]*dCoef[i]/6+fVector[i]/hVector[i]

    return aCoef,bCoef,cCoef[1:],dCoef

def splineCoefficients2(X,Y,A,B):
    N = X.shape[0]-1
    aCoef = np.zeros(N)
    bCoef = np.zeros(N)
   
    dCoef = np.zeros(N)
   
    fVector = np.diff(Y)
    hVector = np.diff(X)
    
    cCoef = np.zeros(N+1)
    FVector = np.zeros(N+1)
        
    FVector[0] = A
    FVector[N] = B
    for i in range(1,N):
        FVector[i] = 6*(fVector[i]/hVector[i] - fVector[i-1]/hVector[i-1])
        
    print(f'f_(i+1)-f_(i): {fVector}')
    print(f'x_(i+1)-x_(i): {hVector}')
    print(f'F: {FVector}')

    aDiag = np.zeros(N)
    bDiag = np.zeros(N)
    cDiag = np.zeros(N+1)
    
    cDiag[0] = 1
    bDiag[0] = 0.5
    cDiag[N] = 1
    aDiag[N-1] = 0

    for i in range(1, N):
        aDiag[i-1] = hVector[i-1]
        cDiag[i] = 2*(hVector[i-1]+hVector[i])
        bDiag[i] = hVector[i]
       
    cCoef = TMA(aDiag, bDiag, cDiag, FVector)
    
    for i in range (N):
        aCoef[i] = Y[i+1]
        
    for i in range(1,N):
        dCoef[i] = (cCoef[i+1]-cCoef[i])
        dCoef[i] = dCoef[i] / hVector[i-1]

    dCoef[0] = (cCoef[1]-cCoef[0])
    dCoef[0] = dCoef[0]/hVector[0]
    
    # bCoef[N-1]=B
    for i in range(0,N):
        bCoef[i] = hVector[i]*cCoef[i+1]/2- hVector[i]*hVector[i]*dCoef[i]/6+fVector[i]/hVector[i]

    return aCoef,bCoef,cCoef[1:],dCoef

def splineCoefficients(X,Y,A,B):
    N = X.shape[0]-1
    aCoef = np.zeros(N)
    bCoef = np.zeros(N)
   
    dCoef = np.zeros(N)
   
    fVector = np.diff(Y)
    hVector = np.diff(X)
    
    cCoef = np.zeros(N+1)
    FVector = np.zeros(N+1)
        
    FVector[0] = 3*(fVector[0]/hVector[0]-A)/hVector[0]
    FVector[N] = 3*(B-fVector[N-1]/hVector[N-1])/hVector[N-1]
    for i in range(1,N):
        FVector[i] = 6*(fVector[i]/hVector[i] - fVector[i-1]/hVector[i-1])
        
    print(f'f_(i+1)-f_(i): {fVector}')
    print(f'x_(i+1)-x_(i): {hVector}')
    print(f'F: {FVector}')

    aDiag = np.zeros(N)
    bDiag = np.zeros(N)
    cDiag = np.zeros(N+1)
    
    cDiag[0] = 1
    bDiag[0] = 0.5

    cDiag[N] = 1
    aDiag[N-1] = 0.5

    for i in range(1, N):
        aDiag[i-1] = hVector[i-1]
        cDiag[i] = 2*(hVector[i-1]+hVector[i])
        bDiag[i] = hVector[i]
       
    cCoef = TMA(aDiag, bDiag, cDiag, FVector)
    
    for i in range (N):
        aCoef[i] = Y[i+1]
        
    for i in range(1,N):
        dCoef[i] = (cCoef[i+1]-cCoef[i])
        dCoef[i] = dCoef[i] / hVector[i-1]

    dCoef[0] = (cCoef[1]-cCoef[0])
    dCoef[0] = dCoef[0]/hVector[0]
    
    # bCoef[N-1]=B
    for i in range(0,N):
        bCoef[i] = hVector[i]*cCoef[i+1]/2- hVector[i]*hVector[i]*dCoef[i]/6+fVector[i]/hVector[i]

    return aCoef,bCoef,cCoef[1:],dCoef
    
def functionDiff(XX, axis, a,b,c,d):
    index = findIntervalIndex(XX, axis)
    YY = b[index]+(XX-axis[index+1])*(c[index] + d[index]*(XX-axis[index+1])/2)
    return YY
def functionVal(XX, axis, a,b,c,d):
    index = findIntervalIndex(XX, axis)
    YY =a[index] + b[index]*(XX-axis[index+1])+ c[index]*(XX-axis[index+1])*(XX-axis[index+1])/2 + d[index]*(XX-axis[index+1])*(XX-axis[index+1])*(XX-axis[index+1])/6
    return YY
    
def findIntervalIndex(XX, axis):
    for i in range(1,axis.shape[0]):
        if (XX <= axis[i]):
            index = i
            break
    print(f'INDEX: {index}')
    return index - 1

def pointInInterval(XX, axis):
    if(axis[0] > XX or axis[-1] < XX):
        return False
    return True

def isAscendingOrder(vector): 
    if not np.all(np.diff(vector) > 0):
        return False
    return True
# a,b,c,d = splineCoefficients1(X,Y,2,6)
# print(f'ai: {a}')
# print(f'bi: {b}')
# print(f'ci: {c}')
# print(f'di: {d}')
# for i in range(X.shape[0]-1):   
#     print(f'многочлен: {a[i]-b[i]*X[i+1]+X[i+1]*X[i+1]*c[i+1]/2-X[i+1]*X[i+1]*X[i+1]*d[i]/6} + {b[i]-c[i+1]*X[i+1]+d[i]*X[i+1]*X[i+1]/2}x + {c[i+1]/2-d[i]*X[i+1]/2}x\u00b2 + {d[i]/6}x\u00b3')
  
# for i in range(X.shape[0]-1):   
#     print(f'многочлен: {a[i]+b[i]*X[i]+X[i]*X[i]*c[i]/2-X[i]*X[i]*X[i]*d[i]/6} + {b[i]-c[i]*X[i]+d[i]*X[i]*X[i]/2}x + {c[i]/2-d[i]*X[i]*X[i]/2}x\u00b2 + {d[i]/6}x\u00b3')
