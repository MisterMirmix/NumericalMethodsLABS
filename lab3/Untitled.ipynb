# %%
# Задание № 1. Решение систем линейных уравнений 
# с разреженными матрицами специального вида
# Во всех вариантах исходные системы уравнений задаются шестью векторами: a, b, c, f, p, q. Векторы a, b, c содержат значения трех диагоналей
# матрицы, f – вектор правой части системы, p, q – векторы для строк или
# столбцов, которые «портят» матрицы системы. 
# В отчете о выполнении задания должны содержаться следующие пункты. 
# 1. Постановка задачи, в том числе запись системы, аналогичная (1), и
# символическое изображение исходной матрицы. 
# 2. Метод решения – символическое изображение алгоритма решения, 
# подобное рис. 1; все вычислительные формулы; число операций прямого и
# обратного хода метода. 
# 3. Основные процедуры – описание входных и выходных параметров, 
# назначение процедуры. Среди основных процедур должна быть процедура
# решения системы уравнений специального вида с входными параметрами n
# (размерность системы), a, b, c, f, p, q (векторы, задающие систему уравнений) и выходными параметрами x (решение), код завершения, оценка точности решения. 
# 4. Результаты тестирования в виде таблицы.
import numpy as np
import pandas as pd
def show_divided_differences(axis, table):
    df = pd.DataFrame(table, columns=[f'X{i}' for i in range(len(axis))],index = [f'F{i}' for i in range(len(axis))])
    df.insert(len(axis),'F', axis)
    print(df)
    return df
def mmm(A,B,C,P,Q):
    N = B.shape[0]
    matrix = np.zeros((N,N))
    
    # matrix[i][i-1] = A[i]
    matrix[0][0] = B[0]
    matrix[0][1] = C[0]
    for i in range(1,N-1):
        matrix[i][i-1] = A[i-1]
        matrix[i][i] = B[i]
        matrix[i][i+1] = C[i]
    for i in range(0,N):
        matrix[i][k] = P[i]
        matrix[i][k+1] = Q[i]
    matrix[N-1][N-2] = A[N-2]
    matrix[N-1][N-1] = B[N-1]
    return matrix


N = 10 
#подиагональ
A = np.zeros(N-1)
#главная диагональ
B = np.zeros(N)
#наддиагональ
C = np.zeros(N-1)
#вектор свободных членов
F = np.zeros(N)
# k-ый столбец
P = np.zeros(N)
# (k+1)-ый столбец
Q = np.zeros(N)
k = 5 - 1
# for i in range (N):
#     B[i] = 1
#     P[i] = 1
#     Q[i] = 1
# for i in range (1,N):
#     B[i] = 2
    
# P[k] = 2
# Q[k+1] = 2
# for i in range (N-1):
#     A[i] = 1
#     C[i] = 1
F = np.array([18.,22.,22.,18.,14.,14.,18.,22.,22.,20.])
A = np.array([4.,4.,4.,4.,4.,4.,4.,4.,4.,4.])
B = np.array([8.,8.,8.,8.,8.,8.,8.,8.,8.,8.])
C = np.array([2.,2.,2.,2.,2.,2.,2.,2.,2.,2.])
P = np.array([4.,4.,4.,2.,8.,4.,4.,4.,4.,4.])
Q = np.array([4.,4.,4.,4.,2.,8.,4.,4.,4.,4.])

print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
    
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

C[0] = C[0]/B[0]
P[0] = P[0]/B[0]
Q[0] = Q[0]/B[0]
F[0] = F[0]/B[0]
B[0] = 1

for i in range (1,k-1):    
    B[i] = B[i]-C[i-1]*A[i-1]
    P[i] = P[i]-P[i-1]*A[i-1]
    Q[i] = Q[i]-Q[i-1]*A[i-1]
    F[i] = F[i]-F[i-1]*A[i-1]
    A[i-1] = 0
    C[i] = C[i]/B[i]
    P[i] = P[i]/B[i]
    Q[i] = Q[i]/B[i]
    F[i] = F[i]/B[i]
    B[i] = 1
    # print(mmm(A,B,C,P,Q))

print("----------------------------------")
print("0,k-2")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

B[k-1] = B[k-1]-C[k-2]*A[k-2]
C[k-1] = C[k-1]-C[k-2]*A[k-2]
P[k-1] = P[k-1]-P[k-2]*A[k-2]
Q[k-1] = Q[k-1]-Q[k-2]*A[k-2]
F[k-1] = F[k-1]-F[k-2]*A[k-2]
A[k-2] = 0
print("----------------------------------")
print("k-1")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

C[k-1] = C[k-1]/B[k-1]
P[k-1] = P[k-1]/B[k-1]
Q[k-1] = Q[k-1]/B[k-1]
F[k-1] = F[k-1]/B[k-1]
B[k-1] = 1
print("----------------------------------")
print("k-1")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

B[k] = B[k]-C[k-1]*A[k-1]
P[k] = P[k]-P[k-1]*A[k-1]
Q[k] = Q[k]-Q[k-1]*A[k-1]
# Q[k]=C[k]
C[k] = C[k]-C[k-1]*A[k-1]
F[k] = F[k]-F[k-1]*A[k-1]
A[k-1] = 0

print("----------------------------------")
print("k-")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

C[k] = C[k]/B[k]
P[k] = P[k]/B[k]
Q[k] = Q[k]/B[k]
# Q[k] = Q[k]/B[k]
F[k] = F[k]/B[k]
B[k] = 1

print("----------------------------------")
print("k/")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

B[k+1] = B[k+1]-C[k]*A[k]
P[k+1] = P[k+1]-P[k]*A[k]
Q[k+1] = Q[k+1]-Q[k]*A[k]
F[k+1] = F[k+1]-F[k]*A[k]
A[k] = 0
print("----------------------------------")
print("k+1 -")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

for i in range(k+2,N):
    F[i] = F[i] - F[k]*P[i]
    Q[i] = Q[i] - Q[k]*P[i]
    P[i] = 0

print("----------------------------------")
print("P[i] = 0")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

# C[k+1] = C[k+1]/B[k+1]
# P[k+1] = P[k+1]/B[k+1]
# Q[k+1] = 1
# F[k+1] = F[k+1]/B[k+1]
# B[k+1] = 1



# print("----------------------------------")
# print("k+1 / ")
# print(f'C: {C}')
# print(f'B: {B}')
# print(f'A: {A}')
# print(f'P: {P}')
# print(f'Q: {Q}')
# print(f'F: {F}')
# print(mmm(A,B,C,P,Q))



# for i in range (k+2,N-1):    
#     B[i] = B[i]-C[i-1]*A[i-1]
#     P[i] = P[i]-P[i-1]*A[i-1]
#     Q[i] = Q[i]-Q[i-1]*A[i-1]
#     F[i] = F[i]-F[i-1]*A[i-1]
#     A[i-1] = 0
#     C[i] = C[i]/B[i]
#     P[i] = P[i]/B[i]
#     Q[i] = Q[i]/B[i]
#     F[i] = F[i]/B[i]
#     B[i] = 1

# print("----------------------------------")
# print(f'C: {C}')
# print(f'B: {B}')
# print(f'A: {A}')
# print(f'P: {P}')
# print(f'Q: {Q}')
# print(f'F: {F}')
# print(mmm(A,B,C,P,Q))

# B[N-1] = B[N-1]-C[N-2]*A[N-2]
# P[N-1] = P[N-1]-P[N-2]*A[N-2]
# Q[N-1] = Q[N-1]-Q[N-2]*A[N-2]
# F[N-1] = F[N-1]-F[N-2]*A[N-2]
# A[N-2] = 0

# P[N-1] = P[N-1]/B[N-1]
# Q[N-1] = Q[N-1]/B[N-1]
# F[N-1] = F[N-1]/B[N-1]
# B[N-1] = 1

# print("----------------------------------")
# print(f'C: {C}')
# print(f'B: {B}')
# print(f'A: {A}')
# print(f'P: {P}')
# print(f'Q: {Q}')
# print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
A[N-2] = A[N-2]/B[N-1]
F[N-1] = F[N-1]/B[N-1]
Q[N-1] = Q[N-1]/B[N-1]
B[N-1] = 1
print("----------------------------------")
print("N/")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

for i in range (N-2,k+1,-1):    
    # C[i-1] = C[i-1] - B[i]
    B[i] = B[i] - A[i]*C[i]
    Q[i] = Q[i] - Q[i+1]*C[i]
    F[i] = F[i] - F[i+1]*C[i]
    C[i] = 0


    A[i-1] = A[i-1]/B[i]
    Q[i] = Q[i]/B[i]
    F[i] = F[i]/B[i]
    B[i] = 1
    # B[i]=99

    # A[i-2] = A[i-2]/B[i]
    # F[N-1] = F[N-1]/B[N-1]
    # Q[N-1] = Q[N-1]/B[N-1]
    # B[N-1] = 1
    # Q[i] = 0

print("----------------------------------")
print("N-2,k+1")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))
# B[k+1] = B[k+1] - A[k+1]*C[k+1]
Q[k+1] = Q[k+1] - Q[k+2]*C[k+1]
B[k+1] = Q[k+1]
F[k+1] = F[k+1] - F[k+2]*C[k+1]
C[k+1] = 0
print("----------------------------------")
print("k+1 -")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))
F[k+1] = F[k+1]/B[k+1]
B[k+1] = 1
Q[k+1] = 1

print("----------------------------------")
print("k+1 /")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))
print(f'vector X: {X}')


for i in range(k+2,N):
    F[i] = F[i] - F[k+1]*Q[i]
    # Q[i] = Q[i] - Q[k]*P[i]
    Q[i] = 0

print("----------------------------------")
print("Q[i] = 0")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

for i in range(k+2,N-1):
    F[i+1] = F[i+1]-F[i]*A[i]
    # F[i] = F[i] - A[i]
    # Q[i] = Q[i] - Q[k]*P[i]
    A[i] = 0
# B[k+1] = 99
# C[k] = 99
# Q[k] = 99
# Q[i] = Q[i] - Q[i+1]*C[i]
# F[i] = F[i] - F[i+1]*C[i]
# C[i] = 0
# Q[k+1] = 1
# B[k+1] = 1
# F[k+1] = F[k+1]/Q[k+1]
   
# X = np.zeros(N)
# for i in range (k+2,N): 
#     F[i] = F[i] - F[k+1]*Q[i]
#     Q[i] = Q[i] - Q[k+1]*Q[i]
    
    # C[i-1] = C[i-1] - B[i]
    
    # X[i] = F[i]




# C[0] = C[0]/B[0]
# P[0] = P[0]/B[0]
# Q[0] = Q[0]/B[0]
# F[0] = F[0]/B[0]
# B[k] = 1
# P[k] = 1
# B[k+1] = 999
# P[k] = 999
# Q[k+1] = 777
# P[k] = P[k]-P[k-1]*A[k-1]
# Q[k] = Q[k]-Q[k-1]*A[k-1]
# F[k] = F[k]-F[k-1]*A[k-1]
# A[k] = 10

# print(C)
# print(B)
# print(A)
# print(P)
# print(Q)
print("----------------------------------")
print(f'C: {C}')
print(f'B: {B}')
print(f'A: {A}')
print(f'P: {P}')
print(f'Q: {Q}')
print(f'F: {F}')
# print(mmm(A,B,C,P,Q))
show_divided_differences(F, mmm(A,B,C,P,Q))

for i in range(N-1,k,-1):
    X[i] = F[i]
X[k] = F[k]-Q[k]*X[k+1]
X[k-1] = F[k-1]-Q[k-1]*X[k]-P[k-1]*X[k+1]

for i in range(k-2,-1,-1):
    X[i] = F[i] - Q[i]*X[k]-P[i]*X[k+1]-C[i]*X[i+1]
print(f'vector X: {X}')
# Out:
# C: [2. 2. 2. 2. 2. 2. 2. 2. 2. 2.]
# B: [8. 8. 8. 8. 8. 8. 8. 8. 8. 8.]
# A: [4. 4. 4. 4. 4. 4. 4. 4. 4. 4.]
# P: [4. 4. 4. 2. 8. 4. 4. 4. 4. 4.]
# Q: [4. 4. 4. 4. 2. 8. 4. 4. 4. 4.]
# F: [18. 22. 22. 18. 14. 14. 18. 22. 22. 20.]
#      X0   X1   X2   X3   X4   X5   X6   X7   X8   X9     F
# F0  8.0  2.0  0.0  0.0  4.0  4.0  0.0  0.0  0.0  0.0  18.0
# F1  4.0  8.0  2.0  0.0  4.0  4.0  0.0  0.0  0.0  0.0  22.0
# F2  0.0  4.0  8.0  2.0  4.0  4.0  0.0  0.0  0.0  0.0  22.0
# F3  0.0  0.0  4.0  8.0  2.0  4.0  0.0  0.0  0.0  0.0  18.0
# F4  0.0  0.0  0.0  4.0  8.0  2.0  0.0  0.0  0.0  0.0  14.0
# F5  0.0  0.0  0.0  0.0  4.0  8.0  2.0  0.0  0.0  0.0  14.0
# F6  0.0  0.0  0.0  0.0  4.0  4.0  8.0  2.0  0.0  0.0  18.0
# F7  0.0  0.0  0.0  0.0  4.0  4.0  4.0  8.0  2.0  0.0  22.0
# F8  0.0  0.0  0.0  0.0  4.0  4.0  0.0  4.0  8.0  2.0  22.0
# F9  0.0  0.0  0.0  0.0  4.0  4.0  0.0  0.0  4.0  8.0  20.0
# ----------------------------------
# 0,k-2
# ...
